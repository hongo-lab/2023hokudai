# %% [markdown]
# # バンドギャップの機械学習

# %% [markdown]
# - バンドギャップの機械学習モデルを構築・検証している先行研究では、GitHubに論文で使用しているpythonコードが公開されているので、そのコードを実際に動かしてみる。
# - 元論文: Zhuo. Y, Mansouri Tehrani., and Brgoch. J, "Predicting the band gaps of inorganic solids by machine learning", J. Phys. Chem. Lett. 2018, 9, 1668-1673. https://doi.org/10.1021/acs.jpclett.8b00124
# - GitHub: https://github.com/yzhuo33/BandGapPredictor

# %%
# !pip install pymatgen xlrd
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 55.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 2.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 9.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 561.4/561.4 kB 50.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 kB 12.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 515.3/515.3 kB 46.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.4/98.4 kB 12.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.3/154.3 kB 18.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.6/485.6 kB 44.7 MB/s eta 0:00:00
# ...

# %%
# !git clone https://github.com/yzhuo33/BandGapPredictor.git
# %cd BandGapPredictor/
# Out:
# Cloning into 'BandGapPredictor'...
# remote: Enumerating objects: 30, done.
# remote: Counting objects: 100% (30/30), done.
# remote: Compressing objects: 100% (28/28), done.
# remote: Total 30 (delta 13), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (30/30), 7.73 MiB | 8.73 MiB/s, done.
# /content/BandGapPredictor/BandGapPredictor

# %%
# !ls
# Out:
# Eg_model.py  elements.xlsx  README.md  to_predict.xlsx	Training_Set.xlsx

# %%
# %run Eg_model.py
# Out:
# A file named predicted.xlsx has been generated.
# Please check your folder.
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(

# %%
# !ls
# Out:
# Eg_model.py    predicted.xlsx  to_predict.xlsx
# elements.xlsx  README.md       Training_Set.xlsx
